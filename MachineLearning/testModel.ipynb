# %%
def decision_tree(features):
    if features[4] <= 1610:
        if features[36] <= 2256:
            if features[0] <= 2385:
                if features[1] <= 410:
                    if features[98] <= 2312:
                        if features[11] <= 1350:
                            return 2
                        else:
                            if features[3] <= 1064:
                                return 2
                            else:
                                if features[27] <= 3202:
                                    return 2
                                else:
                                    return 0
                    else:
                        if features[112] <= 1454:
                            if features[7] <= 824:
                                return 0
                            else:
                                return 2
                        else:
                            return 0
                else:
                    if features[12] <= 104:
                        if features[44] <= 1268:
                            if features[61] <= 481:
                                return 1
                            else:
                                return 0
                        else:
                            return 4
                    else:
                        if features[5] <= 9:
                            if features[13] <= 722:
                                return 0
                            else:
                                return 2
                        else:
                            if features[22] <= 2317:
                                if features[10] <= 676:
                                    if features[2] <= 928:
                                        return 0
                                    else:
                                        if features[5] <= 944:
                                            if features[33] <= 1522:
                                                if features[67] <= 784:
                                                    return 2
                                                else:
                                                    return 0
                                            else:
                                                return 2
                                        else:
                                            return 4
                                else:
                                    if features[7] <= 549:
                                        return 2
                                    else:
                                        if features[1] <= 507:
                                            if features[100] <= 1308:
                                                return 2
                                            else:
                                                return 0
                                        else:
                                            return 0
                            else:
                                return 2
            else:
                if features[2] <= 2966:
                    if features[59] <= 4:
                        if features[2] <= 1370:
                            if features[44] <= 582:
                                return 0
                            else:
                                if features[1] <= 2632:
                                    return 0
                                else:
                                    if features[4] <= 367:
                                        return 0
                                    else:
                                        if features[32] <= 1511:
                                            return 1
                                        else:
                                            return 0
                        else:
                            if features[2] <= 1696:
                                if features[5] <= 808:
                                    return 0
                                else:
                                    return 1
                            else:
                                return 0
                    else:
                        if features[3] <= 894:
                            if features[36] <= 2136:
                                if features[27] <= 120:
                                    if features[40] <= 486:
                                        if features[99] <= 757:
                                            if features[84] <= 372:
                                                if features[3] <= 552:
                                                    return 1
                                                else:
                                                    return 0
                                            else:
                                                return 0
                                        else:
                                            if features[79] <= 644:
                                                return 4
                                            else:
                                                return 0
                                    else:
                                        if features[94] <= 837:
                                            return 0
                                        else:
                                            if features[73] <= 622:
                                                return 4
                                            else:
                                                if features[1] <= 2706:
                                                    return 1
                                                else:
                                                    return 0
                                else:
                                    if features[0] <= 3528:
                                        if features[164] <= 906:
                                            if features[133] <= 349:
                                                if features[36] <= 2015:
                                                    return 0
                                                else:
                                                    if features[59] <= 1236:
                                                        return 1
                                                    else:
                                                        return 0
                                            else:
                                                if features[32] <= 1391:
                                                    return 0
                                                else:
                                                    return 2
                                        else:
                                            if features[30] <= 1402:
                                                return 0
                                            else:
                                                return 1
                                    else:
                                        if features[50] <= 2428:
                                            if features[2] <= 2454:
                                                if features[4] <= 1120:
                                                    if features[54] <= 2472:
                                                        if features[179] <= 3642:
                                                            if features[124] <= 1626:
                                                                if features[186] <= 1822:
                                                                    if features[36] <= 2064:
                                                                        return 0
                                                                    else:
                                                                        if features[3] <= 141:
                                                                            if features[59] <= 1172:
                                                                                if features[31] <= 1670:
                                                                                    return 0
                                                                                else:
                                                                                    return 1
                                                                            else:
                                                                                return 0
                                                                        else:
                                                                            return 0
                                                                else:
                                                                    return 1
                                                            else:
                                                                if features[139] <= 1776:
                                                                    if features[90] <= 2262:
                                                                        return 0
                                                                    else:
                                                                        return 1
                                                                else:
                                                                    return 1
                                                        else:
                                                            return 1
                                                    else:
                                                        if features[35] <= 1833:
                                                            if features[61] <= 2150:
                                                                return 0
                                                            else:
                                                                if features[45] <= 826:
                                                                    return 3
                                                                else:
                                                                    return 0
                                                        else:
                                                            return 1
                                                else:
                                                    if features[2] <= 618:
                                                        if features[69] <= 1138:
                                                            return 0
                                                        else:
                                                            return 1
                                                    else:
                                                        return 0
                                            else:
                                                if features[143] <= 561:
                                                    if features[9] <= 1178:
                                                        return 0
                                                    else:
                                                        if features[7] <= 995:
                                                            return 2
                                                        else:
                                                            return 0
                                                else:
                                                    return 2
                                        else:
                                            if features[3] <= 110:
                                                return 1
                                            else:
                                                return 0
                            else:
                                if features[3] <= 210:
                                    if features[82] <= 1509:
                                        if features[5] <= 334:
                                            return 0
                                        else:
                                            if features[57] <= 1372:
                                                return 1
                                            else:
                                                return 0
                                    else:
                                        return 0
                                else:
                                    return 0
                        else:
                            if features[0] <= 3030:
                                if features[1] <= 2044:
                                    if features[42] <= 1504:
                                        return 0
                                    else:
                                        return 4
                                else:
                                    if features[149] <= 114:
                                        if features[26] <= 264:
                                            return 4
                                        else:
                                            return 0
                                    else:
                                        return 2
                            else:
                                if features[81] <= 4:
                                    if features[18] <= 112:
                                        if features[40] <= 641:
                                            return 0
                                        else:
                                            if features[8] <= 409:
                                                if features[49] <= 954:
                                                    return 0
                                                else:
                                                    return 3
                                            else:
                                                return 2
                                    else:
                                        if features[4] <= 822:
                                            if features[32] <= 1284:
                                                if features[55] <= 2222:
                                                    return 0
                                                else:
                                                    if features[11] <= 348:
                                                        return 0
                                                    else:
                                                        if features[51] <= 1160:
                                                            return 0
                                                        else:
                                                            return 3
                                            else:
                                                if features[17] <= 698:
                                                    if features[60] <= 1014:
                                                        return 3
                                                    else:
                                                        return 0
                                                else:
                                                    return 0
                                        else:
                                            return 0
                                else:
                                    if features[98] <= 754:
                                        if features[4] <= 12:
                                            if features[58] <= 1418:
                                                return 0
                                            else:
                                                return 2
                                        else:
                                            if features[157] <= 2287:
                                                if features[1] <= 4079:
                                                    if features[23] <= 30:
                                                        if features[136] <= 399:
                                                            return 0
                                                        else:
                                                            return 2
                                                    else:
                                                        if features[72] <= 5:
                                                            if features[67] <= 2484:
                                                                return 0
                                                            else:
                                                                return 3
                                                        else:
                                                            if features[3] <= 2698:
                                                                if features[0] <= 3182:
                                                                    if features[152] <= 56:
                                                                        return 0
                                                                    else:
                                                                        return 2
                                                                else:
                                                                    if features[185] <= 15:
                                                                        if features[96] <= 2:
                                                                            if features[5] <= 154:
                                                                                if features[1] <= 3442:
                                                                                    return 0
                                                                                else:
                                                                                    return 2
                                                                            else:
                                                                                if features[18] <= 22:
                                                                                    if features[52] <= 864:
                                                                                        return 0
                                                                                    else:
                                                                                        if features[5] <= 566:
                                                                                            return 3
                                                                                        else:
                                                                                            return 2
                                                                                else:
                                                                                    return 0
                                                                        else:
                                                                            if features[1] <= 1362:
                                                                                return 4
                                                                            else:
                                                                                if features[105] <= 838:
                                                                                    return 0
                                                                                else:
                                                                                    if features[108] <= 94:
                                                                                        if features[99] <= 263:
                                                                                            return 4
                                                                                        else:
                                                                                            return 0
                                                                                    else:
                                                                                        return 0
                                                                    else:
                                                                        return 1
                                                            else:
                                                                return 4
                                                else:
                                                    if features[21] <= 113:
                                                        return 3
                                                    else:
                                                        return 0
                                            else:
                                                return 1
                                    else:
                                        if features[22] <= 114:
                                            if features[123] <= 648:
                                                if features[37] <= 482:
                                                    if features[8] <= 266:
                                                        return 0
                                                    else:
                                                        if features[5] <= 796:
                                                            return 4
                                                        else:
                                                            return 0
                                                else:
                                                    if features[14] <= 354:
                                                        return 0
                                                    else:
                                                        return 2
                                            else:
                                                return 2
                                        else:
                                            if features[1] <= 1930:
                                                if features[2] <= 1241:
                                                    return 0
                                                else:
                                                    return 4
                                            else:
                                                if features[26] <= 896:
                                                    if features[67] <= 1272:
                                                        if features[4] <= 1127:
                                                            if features[25] <= 106:
                                                                if features[4] <= 858:
                                                                    if features[37] <= 470:
                                                                        return 4
                                                                    else:
                                                                        return 2
                                                                else:
                                                                    return 0
                                                            else:
                                                                if features[6] <= 524:
                                                                    if features[19] <= 54:
                                                                        if features[59] <= 704:
                                                                            return 0
                                                                        else:
                                                                            return 2
                                                                    else:
                                                                        return 0
                                                                else:
                                                                    if features[3] <= 1397:
                                                                        if features[1] <= 3478:
                                                                            if features[2] <= 1931:
                                                                                return 0
                                                                            else:
                                                                                return 4
                                                                        else:
                                                                            return 0
                                                                    else:
                                                                        if features[2] <= 2570:
                                                                            return 4
                                                                        else:
                                                                            return 0
                                                        else:
                                                            return 0
                                                    else:
                                                        if features[26] <= 470:
                                                            return 2
                                                        else:
                                                            if features[37] <= 1565:
                                                                return 0
                                                            else:
                                                                return 2
                                                else:
                                                    if features[86] <= 3262:
                                                        if features[7] <= 12:
                                                            return 2
                                                        else:
                                                            return 0
                                                    else:
                                                        if features[4] <= 117:
                                                            return 2
                                                        else:
                                                            return 0
                else:
                    if features[25] <= 118:
                        if features[55] <= 675:
                            if features[1] <= 3492:
                                return 4
                            else:
                                return 0
                        else:
                            return 2
                    else:
                        if features[18] <= 100:
                            if features[9] <= 375:
                                if features[95] <= 64:
                                    return 3
                                else:
                                    return 0
                            else:
                                if features[1] <= 3702:
                                    return 0
                                else:
                                    return 2
                        else:
                            if features[56] <= 2418:
                                if features[33] <= 396:
                                    if features[6] <= 1480:
                                        if features[56] <= 743:
                                            return 0
                                        else:
                                            if features[27] <= 402:
                                                return 2
                                            else:
                                                return 0
                                    else:
                                        return 4
                                else:
                                    if features[23] <= 80:
                                        return 2
                                    else:
                                        if features[68] <= 2148:
                                            return 0
                                        else:
                                            return 0
                            else:
                                if features[0] <= 3814:
                                    return 3
                                else:
                                    return 0
        else:
            if features[8] <= 366:
                if features[4] <= 508:
                    if features[16] <= 920:
                        return 0
                    else:
                        if features[11] <= 1657:
                            return 2
                        else:
                            return 0
                else:
                    if features[138] <= 72:
                        if features[1] <= 3142:
                            if features[31] <= 3760:
                                return 4
                            else:
                                return 2
                        else:
                            return 2
                    else:
                        if features[57] <= 1338:
                            return 0
                        else:
                            return 2
            else:
                if features[2] <= 1938:
                    if features[16] <= 2328:
                        if features[10] <= 1146:
                            if features[1] <= 2828:
                                if features[33] <= 2558:
                                    if features[87] <= 1074:
                                        return 0
                                    else:
                                        return 1
                                else:
                                    if features[71] <= 1750:
                                        return 2
                                    else:
                                        return 0
                            else:
                                if features[86] <= 1053:
                                    if features[52] <= 1732:
                                        return 0
                                    else:
                                        return 2
                                else:
                                    if features[27] <= 1446:
                                        return 0
                                    else:
                                        if features[43] <= 2010:
                                            return 1
                                        else:
                                            if features[30] <= 2191:
                                                return 0
                                            else:
                                                return 1
                        else:
                            if features[3] <= 798:
                                if features[0] <= 20:
                                    return 2
                                else:
                                    if features[10] <= 1352:
                                        if features[4] <= 287:
                                            return 2
                                        else:
                                            if features[1] <= 3534:
                                                return 0
                                            else:
                                                return 1
                                    else:
                                        return 0
                            else:
                                return 0
                    else:
                        if features[48] <= 3456:
                            if features[0] <= 3468:
                                return 2
                            else:
                                return 0
                        else:
                            if features[12] <= 3042:
                                return 0
                            else:
                                return 2
                else:
                    if features[8] <= 827:
                        if features[4] <= 788:
                            if features[34] <= 2422:
                                return 0
                            else:
                                return 2
                        else:
                            if features[1] <= 3396:
                                return 4
                            else:
                                return 0
                    else:
                        if features[0] <= 4089:
                            return 0
                        else:
                            if features[41] <= 2564:
                                return 0
                            else:
                                return 2
    else:
        if features[12] <= 1214:
            if features[102] <= 1408:
                if features[1] <= 2898:
                    if features[2] <= 1704:
                        if features[29] <= 1318:
                            return 0
                        else:
                            return 2
                    else:
                        if features[50] <= 538:
                            return 1
                        else:
                            return 4
                else:
                    if features[7] <= 1416:
                        if features[130] <= 702:
                            if features[2] <= 3524:
                                if features[40] <= 2412:
                                    if features[83] <= 12:
                                        if features[26] <= 650:
                                            if features[59] <= 138:
                                                return 0
                                            else:
                                                return 2
                                        else:
                                            return 0
                                    else:
                                        if features[18] <= 190:
                                            return 2
                                        else:
                                            return 0
                                else:
                                    return 4
                            else:
                                if features[58] <= 2458:
                                    if features[43] <= 2086:
                                        return 2
                                    else:
                                        return 4
                                else:
                                    return 3
                        else:
                            return 2
                    else:
                        if features[26] <= 1117:
                            if features[3] <= 2099:
                                return 0
                            else:
                                return 2
                        else:
                            if features[44] <= 1730:
                                return 0
                            else:
                                return 4
            else:
                if features[26] <= 188:
                    if features[84] <= 922:
                        if features[1] <= 3325:
                            return 4
                        else:
                            return 0
                    else:
                        return 2
                else:
                    if features[130] <= 49:
                        if features[33] <= 72:
                            return 0
                        else:
                            if features[22] <= 102:
                                return 0
                            else:
                                return 4
                    else:
                        if features[45] <= 2136:
                            return 2
                        else:
                            return 4
        else:
            if features[33] <= 1074:
                if features[23] <= 672:
                    if features[57] <= 1034:
                        return 4
                    else:
                        return 2
                else:
                    if features[55] <= 1026:
                        if features[58] <= 16:
                            return 4
                        else:
                            return 0
                    else:
                        if features[6] <= 1700:
                            return 0
                        else:
                            return 4
            else:
                if features[21] <= 3904:
                    if features[10] <= 932:
                        return 4
                    else:
                        if features[15] <= 1228:
                            if features[99] <= 751:
                                return 0
                            else:
                                return 4
                        else:
                            if features[24] <= 3958:
                                if features[41] <= 2192:
                                    if features[0] <= 4076:
                                        if features[107] <= 1406:
                                            if features[2] <= 1974:
                                                if features[26] <= 1949:
                                                    return 0
                                                else:
                                                    return 2
                                            else:
                                                if features[99] <= 2152:
                                                    return 0
                                                else:
                                                    return 4
                                        else:
                                            return 0
                                    else:
                                        if features[1] <= 2210:
                                            return 4
                                        else:
                                            return 0
                                else:
                                    if features[8] <= 1214:
                                        return 4
                                    else:
                                        if features[13] <= 1310:
                                            return 4
                                        else:
                                            if features[64] <= 3972:
                                                if features[3] <= 1272:
                                                    if features[19] <= 3266:
                                                        return 0
                                                    else:
                                                        return 2
                                                else:
                                                    return 0
                                            else:
                                                return 2
                            else:
                                if features[39] <= 2998:
                                    if features[0] <= 79:
                                        return 2
                                    else:
                                        return 0
                                else:
                                    return 0
                else:
                    if features[2] <= 1037:
                        return 2
                    else:
                        if features[3] <= 2074:
                            return 1
                        else:
                            return 0

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
df2 = pd.read_csv('Data/mitbih_test_processed.csv')
X_test, y_test = df2.iloc[:, :-1], df2.iloc[:, -1]

# %%
y_pred = X_test.apply(lambda row: decision_tree(row.values), axis=1)

accuracy = accuracy_score(y_test, y_pred)
print(f"Decision Tree Accuracy: {accuracy:.4f}")
# Out:
# Decision Tree Accuracy: 0.9607
